# %%
currentNumber = 1
product = 1
threshhold = 100
while product in range(1, 101):
    product = product * currentNumber
    if product > 100:
        currentNumber -= 1
    currentNumber += 1

print(f"The final integer is {currentNumber}.")
print(f"The final product is {product}.")
# while loop was used to keep the threshold in place using the range function.
# The if statement was used so that the currentNumber
# would not add +1 after the product exceeded 100.
# Out:
# The final integer is 5.
# The final product is 120.
