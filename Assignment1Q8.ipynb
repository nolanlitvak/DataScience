# %%
import pandas as pd
data = {
    "A" : [1, 2, 2, 1],
    "B" : [3.1, 4.2, 1.5, 6.3],
    "C" : [800, 150, 400, 210]
}
data_frame = pd.DataFrame(data)
data_frame["Z"] = data_frame["B"] - data_frame["A"]
print(data_frame)
# Out:
#    A    B    C    Z
# 0  1  3.1  800  2.1
# 1  2  4.2  150  2.2
# 2  2  1.5  400 -0.5
# 3  1  6.3  210  5.3
